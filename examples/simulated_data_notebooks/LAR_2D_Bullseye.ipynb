# %% [markdown]
# How did you start Notebook
# --------------------------
#
# When starting this notebook using this:
# ```bash
# ~/tutorial-env/bin/ipython notebook --pylab=inline
#
# ```
# comment out the code in the following cell.

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# **Generate the data necessary to this project first.**

# %%
import tempfile
figure()
data_folder=tempfile.mkdtemp()
print "Generated input data is saved in: "+data_folder
# %run ../../helper/gen_2D_simulation_data.py $data_folder
# Out:
# Generated input data is saved in: /tmp/tmpRnD5Nh

# %%
import glob
import sys
import os.path
sys.path.append('../')
sys.path.append('../../')
from pyLAR import *
import SimpleITK as sitk

# %%
# global parameters
EXE_ConvertToJpg = '/Users/xiaoxiaoliu/work/bin/ANTS/bin/ConvertToJpg'
input_folder = data_folder
result_folder = data_folder +'/LRA_Results'
UAB_result_folder = data_folder +'/UAB_Results'
GT_UAB_result_folder = data_folder +'/GT_UAB_Results'
if not os.path.exists(result_folder):
    os.makedirs(result_folder)
if not os.path.exists(UAB_result_folder):
    os.makedirs( UAB_result_folder)
if not os.path.exists(GT_UAB_result_folder):
    os.makedirs( GT_UAB_result_folder)

im_names = glob.glob(input_folder+'/simu*.*')

num_of_data = len(im_names)
x_dim = 64
y_dim = 64

VIS = 1
#print im_names

# data selection
selection = range(num_of_data)
num_of_data = len(selection)



NUM_OF_ITERATIONS = 10

USE_HEALTHY_ATLAS_AS_REF = 0
refHealthyAtlas = data_folder + '/fMeanSimu'+'.nrrd'

# %%
def getImageArray(fn, CONVERT= False):
    if CONVERT:
        img = Image.open(fn).convert('LA')
        newImFn = os.path.splitext(fn)[0]+'.png'
        img.save(newImFn)
        convertToJpg(newImFn)
        os.system('rm '+newImFn)
        newImFn = os.path.splitext(fn)[0]+'.jpg'
        fn = newImFn
    
    im = sitk.ReadImage(fn)
    im_array = sitk.GetArrayFromImage(im)
    return im_array

def convertToJpg(fn):
    outputFn = os.path.splitext(fn)[0]+'.jpg'
    cmd = EXE_ConvertToJpg + ' ' + fn + ' ' + outputFn
    os.system(cmd)
    return outputFn

# %%
###############################  the main LAB (low-rank atlas building) pipeline #############################
def runLABIteration(currentIter, sigma,lamda):
    # run RPCA
    Y = np.zeros((x_dim*y_dim,num_of_data))
    for i in range(num_of_data) :
        im_file =  result_folder+'/'+ 'Iter'+str(currentIter - 1)+'_' + str(i)  + '.nrrd'  
        inIm = sitk.ReadImage(im_file)
        outIm = inIm
        if sigma > 0:
            srg = sitk.SmoothingRecursiveGaussianImageFilter()
            srg.SetSigma(sigma)
            outIm = srg.Execute(inIm)
        tmp = sitk.GetArrayFromImage(outIm)
        Y[:,i] = tmp.reshape(-1)
    
    low_rank, sparse, n_iter,rank, sparsity, sparseness = rpca(Y,lamda)
    saveImagesFromDM(low_rank, result_folder+'/'+ 'Iter'+str(currentIter) +'_LowRank_')
    saveImagesFromDM(sparse, result_folder+'/'+ 'Iter'+str(currentIter) +'_Sparse_')
    
    
    # visualize and inspect
    if VIS == 1:
        fig = plt.figure(figsize=(15,5))
        showSlice(Y, 'Iter'+str(currentIter) +' Input',cm.gray,0)    
        showSlice(low_rank,'Iter'+str(currentIter) +' low rank',cm.gray,1)
        showSlice(sparse,'Iter'+str(currentIter) +' sparse',cm.gray,2)
        savefig(result_folder+'/'+'Iter'+ str(currentIter)+'.png')
    
    atlasIm = ''
    if USE_HEALTHY_ATLAS_AS_REF == 0:
     # Compute the mean of low_rank as the atlas image
        atlasIm = result_folder + '/average_iter'+str(currentIter)+'.nrrd'
        if currentIter == 1 :
            averageImageFromDM(low_rank,atlasIm)     
        else:
            A = np.zeros((x_dim*y_dim,num_of_data))
            for i in range(num_of_data):
                # get inverse transformed low rank image
                lowRankIm = result_folder+'/'+ 'Iter'+str(currentIter)+'_LowRank_' + str(i)  +'.nrrd'
                invWarpedlowRankIm = result_folder+'/Iter'+str(currentIter)+ '_InvWarped_LowRank_' + str(i)  +'.nrrd'
                previousOutputTransformPrefix = result_folder+'/Iter'+ str(currentIter-1)+'_'+str(i)+'_'
                ANTSWarp2DImage(EXE_WarpImageMultiTransform, lowRankIm,invWarpedlowRankIm, lowRankIm,previousOutputTransformPrefix,True, True)
                tmp = getImageArray(lowRankIm)
                A[:,i] = tmp.reshape(-1)
            averageImageFromDM(A,atlasIm)
    else:
        atlasIm = refHealthyAtlas
   
        
    atlas = getImageArray(atlasIm)
   
    # register low-rank images to the atlas(average) image
    for i in range(num_of_data):
        newInputImage = result_folder+'/Iter'+ str(currentIter)+'_' +str(i) +  '.nrrd'
        print newInputImage
        initialInputImage = result_folder+'/Iter0_' +str(i) +  '.nrrd'

        # deform with an intial moving transform from previous iteration
        initialTransform = None
        invWarpedlowRankIm = result_folder+'/'+ 'Iter1_LowRank_' + str(i)  +'.nrrd'
        if currentIter > 1:
            if USE_HEALTHY_ATLAS_AS_REF == 0:
                invWarpedlowRankIm = result_folder+'/Iter'+str(currentIter)+ '_InvWarped_LowRank_' + str(i)  +'.nrrd'
            else:
                initialTransform = result_folder + '/Iter'+str(currentIter-1)+'_'+str(i)+'_0Warp.nii.gz'
            
        # register the inversely warped low rank image to the atlas image
        outputTransformPrefix = result_folder +'/Iter' + str(currentIter) +'_'+str(i)+'_' 
        cmd = ANTS(EXE_ANTS, atlasIm, invWarpedlowRankIm,outputTransformPrefix,antsParams, initialTransform, True)
        # Update input image for the next iteration
        cmd = ANTSWarp2DImage(EXE_WarpImageMultiTransform, initialInputImage,newInputImage, atlasIm,outputTransformPrefix, False,True)
       
    return
    
    
######################################## Run Low-rank Atlas Buildling #######################
def  runLAB(lamda):
    print "lamda = ",lamda
    sigma = 0
    for k in range(1,NUM_OF_ITERATIONS+1):
        print 'iter'+str(k)
        runLABIteration(k,sigma,lamda)
        
    if USE_HEALTHY_ATLAS_AS_REF == 0 :
       # print " low-rank atlas over iterations"
        plt.figure(figsize=(15,10))
        for currentIter in range(1,NUM_OF_ITERATIONS+1):
            fn = result_folder+ '/average_iter'+ str(currentIter) +'.nrrd'
            im_array = getImageArray(fn)
            plt.subplot(1,NUM_OF_ITERATIONS,currentIter)
            plt.imshow(im_array,cm.gray) 
            plt.title( 'LAB Iter'+str(currentIter))
    
        ###########  comparison vis #############
        plt.figure(figsize=(15,5))
        fn1 = result_folder + '/average_iter'+str(NUM_OF_ITERATIONS)+'.nrrd'
        im_array_ula = getImageArray(fn1)


        im_array_gt = getImageArray(refHealthyAtlas)
   
        diff = im_array_ula-im_array_gt
        plt.title('diff')
        plt.imshow(diff,cm.gray,vmin = -80, vmax = 80)

        print 'max =',np.max(diff)
        print 'min =',np.min(diff)

        a = sum(sum(pow(diff,2)))
        print 'total ssd = ',a
    
        fn2 = refHealthyAtlas
        b = geodesicDistance(fn1,fn2,  result_folder + '/average_iter'+str(NUM_OF_ITERATIONS)+'_'+str(lamda))
        print 'geodesic distance = ',b
    
        return a,b
    else:
        im_array_gt = getImageArray(refHealthyAtlas)
       
        
        a= zeros(NUM_OF_ITERATIONS)
        for currentIter in range(1,NUM_OF_ITERATIONS+1):
             s = zeros(num_of_data)
             for i in range(num_of_data):
                fn = result_folder+ '/Iter'+str(currentIter)+'_LowRank_' + str(i)  +'.nrrd'
                im_array = getImageArray(fn)
                diff = im_array-im_array_gt
                s[i] = sum(sum(pow(diff,2)))
             print 'iter',currentIter,'ssd =',s
             a[currentIter-1] = np.average(s)
        print 'avearge ssd over the iterations = ',a
            
        return a

# %%
print 'Simulated Bullseye dataset with added varying-size circles:'
plt.figure(figsize=(20,10)) 
for i in range(num_of_data):
        fn = im_names[selection[i]]
        im_array = getImageArray(fn)
        plt.subplot(1,num_of_data,i+1)
        plt.imshow(im_array,cm.gray,vmin = 0, vmax = 100) 
        plt.axis('off')  
        iter0Fn = result_folder+'/Iter0_'+str(i)+'.nrrd'
       
        im = sitk.GetImageFromArray(im_array)
        sitk.WriteImage(im,iter0Fn)
# Out:
# Simulated Bullseye dataset with added varying-size circles:

# %% [markdown]
# **Configure software paths in cell below**

# %%
EXE_ANTS = '/home/fbudin/Tools/ANTs.2.1.0.Debian-Ubuntu_X64/antsRegistration'
EXE_WarpImageMultiTransform = '/home/fbudin/Tools/ANTs.2.1.0.Debian-Ubuntu_X64/WarpImageMultiTransform'

# %%
# Testing ANTS registration, set parameters
fixedIm =  result_folder+'/Iter0_'+str(0)+'.nrrd'
movingIm =  result_folder+'/Iter0_'+str(3)+'.nrrd'


antsParams =  {
'Dimension': 2,\
'Convergence' : '[100x100,1e-3,10]',\
'ShrinkFactors' : '2x1',\
'SmoothingSigmas' : '1x0vox',\
'Transform' :'SyN[0.1,1,0]',\
#'Metric': 'Mattes[%s,%s,1,50]' %(fixedIm, movingIm)
'Metric': 'MeanSquares[fixedIm,movingIm, 1,0]' # the file name will be replaced inside the ANTS()
}
# Mattes[f,m ,weight, histogramb_in_size,samplingmethod, samplingPercentage]     
#'Metric': 'Mattes[%s,%s,1,50]' %(fixedIm, movingIm)}

cmd = ANTS(EXE_ANTS, fixedIm, movingIm,result_folder+'/test',antsParams)
#print cmd
os.system(cmd)
warpedImFn = result_folder+ '/testWarped.nrrd'
#warpedImFn = convertToJpg(warpedImFn)

plt.figure(figsize=(10,3))
plt.subplot(131)
plt.title('fixed')
plt.imshow(getImageArray(fixedIm),cm.gray) 
plt.subplot(132)
plt.title('moving')
plt.imshow(getImageArray(movingIm),cm.gray) 
plt.subplot(133)
plt.title('warped')
plt.imshow(getImageArray(warpedImFn),cm.gray) 

plt.figure()
diff=getImageArray(warpedImFn)-getImageArray(fixedIm)
a = sum(sum(pow(diff,2)))
print 'total ssd = ',a
plt.imshow(diff,cm.gray,vmin = -20, vmax = 20)
# Out:
# total ssd =  116218.0

# %%
def saveImagesFromDM(D, filePrefix):
    for i in range(num_of_data):
        im_array = np.array(D[:,i].reshape(x_dim, y_dim))
        im = sitk.GetImageFromArray(im_array)
        sitk.WriteImage(im,filePrefix +str(i)+ '.nrrd')
        
def averageImageFromDM(D, fileName):        
        m = np.average(D,1)
        atlas = m.reshape(x_dim,y_dim)
        im = sitk.GetImageFromArray(atlas)
        sitk.WriteImage(im,fileName)
        
def showSlice(D, titleN,color,row, referenceIm=None):
    for i in range(num_of_data):
       im = np.array(D[:,i].reshape(x_dim,y_dim))
        
       plt.subplot2grid((3,num_of_data),(row,i))
       plt.imshow(im,cm.gray)
       plt.axis('off')
       plt.title(titleN+' '+str(i))

# %%
# traditional unbiased atlas building (UAB)
def runUABIteration(currentIter,result_path):
     
    atlasIm = result_path + '/average_UAB_iter'+str(currentIter-1)+'.nrrd'
    
    for i in range(num_of_data):
        initialInputImage = result_path+'/Iter0_' +str(i) +  '.nrrd'
        newInputImage = result_path+'/Iter'+ str(currentIter)+'_' +str(i) +  '.nrrd'
          
        # deform with an intial moving transform from previous iteration
        initialTransform = None
            
        outputTransformPrefix = result_path +'/Iter' + str(currentIter) +'_'+str(i)+'_' 
        # usage: ANTS(fixedIm,movingIm,outputTransformPrefix,params,initialTransform=None, EXECUTE = False):
        cmd = ANTS(EXE_ANTS, atlasIm, initialInputImage,outputTransformPrefix,antsParams, initialTransform, True)
        # Update input image to update the average image
        ## ANTSWarp2DImage(inputIm, outputIm, referenceIm, transformPrefix,inverse = False, EXECUTE = False):
        # ANTSWarp2DImage(initialInputImage,newInputImage, atlasIm,outputTransformPrefix, False,True)
          
   
    A = np.zeros((x_dim*y_dim,num_of_data))
    for i in range(num_of_data):
        #fn = result_path+'/Iter'+ str(currentIter)+'_' +str(i) +  '.nrrd'
        fn = result_path+'/Iter'+ str(currentIter)+'_' +str(i)+'_Warped.nrrd'
        im_array = getImageArray(fn)
        A[:,i] = im_array.reshape(-1)
    newAtlasIm = result_path + '/average_UAB_iter'+str(currentIter)+'.nrrd'  
    averageImageFromDM(A,newAtlasIm)
        
    newAtlas = getImageArray(newAtlasIm)

    plt.subplot(1,NUM_OF_ITERATIONS+2,currentIter+1)
    plt.imshow(newAtlas, cm.gray)
    plt.title( 'Iter %s UAB atlas' %(currentIter))
    plt.axis('off')
          
       
    return


###################################### run UAB #######################

def  runUAB(result_path):
    Y = np.zeros((x_dim*y_dim,num_of_data))
    for i in range(num_of_data):
        fn = result_path +'/Iter0_'+str(i)+'.nrrd'
        im_array = getImageArray(fn)
        Y[:,i] = im_array.reshape(-1)
    m = np.average(Y,1)
    atlas = m.reshape(x_dim,y_dim)
    im = sitk.GetImageFromArray(atlas) 
    sitk.WriteImage(im,result_path +'/average_UAB_iter0.nrrd')
    plt.figure(figsize=(20,10))
    plt.subplot(1,NUM_OF_ITERATIONS+2,1)
    plt.imshow(atlas, cm.gray,vmin = 0, vmax = 80)
    plt.title( 'Iter 0 UAB atlas')
    plt.axis('off')
    
    for k in range(1,NUM_OF_ITERATIONS+1):
        print 'iter'+str(k)
        runUABIteration(k,result_path)
    
    ###########  comparison vis #############
    fn = data_folder + '/fMeanSimu'+'.nrrd'
    im_array_gt = getImageArray(fn)

    fn = result_path + '/average_UAB_iter'+str(NUM_OF_ITERATIONS)+'.nrrd'
    im_array = getImageArray(fn)
    
   
    diff = im_array - im_array_gt
    print 'max =',np.max(diff)
    print 'min =',np.min(diff)
    plt.subplot(1,NUM_OF_ITERATIONS+2,NUM_OF_ITERATIONS+2)
    plt.imshow(diff,cm.gray,vmin = -80, vmax = 80)
    plt.title('diff')
    plt.axis('off') 
    
    a = sum(sum(pow(diff,2)))
    print 'total ssd = ',a
    return a

# %%
def geodesicDistance(inputImage, referenceImage, outputTransformPrefix):
    antsParams =  {
    'Dimension': 2,\
    'Convergence' : '[50x25,1e-6,10]',\
    'ShrinkFactors' : '2x1',\
    'SmoothingSigmas' : '1x0vox',\
    'Transform' :'TimeVaryingVelocityField[0.5,4,3,0,0,0]',\
    'Metric': 'MeanSquares[fixedIm,movingIm, 1,0]' # the file name will be replaced inside the ANTS()
    }
    ANTS(EXE_ANTS, inputImage, referenceImage,outputTransformPrefix,antsParams, None, True)
    logFile = outputTransformPrefix+'ANTS.log'
    geodesicDis = getANTSOutputVelocityNorm(logFile)
    return geodesicDis

# %%
if USE_HEALTHY_ATLAS_AS_REF == 0 :
    lamdaList = [0.3]# arange(0.3,2.5,0.1)
    d1 = np.zeros(len(lamdaList))
    d2 = np.zeros(len(lamdaList))
    for i in range(len(lamdaList)):
        d1[i],d2[i] = runLAB(lamdaList[i])
    plt.figure()
    plt.plot(lamdaList, d1)
    print d1
    plt.title('Unbiased Low-rank Atlas SSD')
    plt.xlabel('Weight')


    plt.figure()
    plt.plot(lamdaList, d2)
    print d2
    plt.title('Unbiased Low-rank Atlas geodesic distance')
    plt.xlabel('Weight')
else:
    d = runLAB(1.0)
    plt.figure()
    plt.plot(d)
    plt.title('LAR SSD')
    print d
# Out:
# lamda =  0.3
# iter1
# [iter: 0000]: rank(P) = 0001, |C|_0 = 5196, crit=0.3107223226, total sparse =150477
# [iter: 0010]: rank(P) = 0001, |C|_0 = 9107, crit=0.0016486236, total sparse =73992
# [iter: 0020]: rank(P) = 0001, |C|_0 = 12070, crit=0.0000272728, total sparse =73737
# [iter: 0030]: rank(P) = 0001, |C|_0 = 16761, crit=0.0000005662, total sparse =73737
# RPCA takes:0.155400 seconds
# /tmp/tmpRnD5Nh/LRA_Results/Iter1_0.nrrd
# /tmp/tmpRnD5Nh/LRA_Results/Iter1_1.nrrd
# /tmp/tmpRnD5Nh/LRA_Results/Iter1_2.nrrd
# /tmp/tmpRnD5Nh/LRA_Results/Iter1_3.nrrd
# /tmp/tmpRnD5Nh/LRA_Results/Iter1_4.nrrd
# /tmp/tmpRnD5Nh/LRA_Results/Iter1_5.nrrd
# /tmp/tmpRnD5Nh/LRA_Results/Iter1_6.nrrd
# /tmp/tmpRnD5Nh/LRA_Results/Iter1_7.nrrd
# iter2
# [iter: 0000]: rank(P) = 0001, |C|_0 = 5197, crit=0.3106527907, total sparse =150531
# [iter: 0010]: rank(P) = 0001, |C|_0 = 9764, crit=0.0022454986, total sparse =74662
# [iter: 0020]: rank(P) = 0001, |C|_0 = 16249, crit=0.0000318282, total sparse =74763
# [iter: 0030]: rank(P) = 0001, |C|_0 = 20159, crit=0.0000005820, total sparse =74760
# RPCA takes:0.209393 seconds
# /tmp/tmpRnD5Nh/LRA_Results/Iter2_0.nrrd
# /tmp/tmpRnD5Nh/LRA_Results/Iter2_1.nrrd
# /tmp/tmpRnD5Nh/LRA_Results/Iter2_2.nrrd
# /tmp/tmpRnD5Nh/LRA_Results/Iter2_3.nrrd
# /tmp/tmpRnD5Nh/LRA_Results/Iter2_4.nrrd
# /tmp/tmpRnD5Nh/LRA_Results/Iter2_5.nrrd
# /tmp/tmpRnD5Nh/LRA_Results/Iter2_6.nrrd
# /tmp/tmpRnD5Nh/LRA_Results/Iter2_7.nrrd
# iter3
# [iter: 0000]: rank(P) = 0001, |C|_0 = 5196, crit=0.3106424473, total sparse =150456
# [iter: 0010]: rank(P) = 0001, |C|_0 = 9967, crit=0.0021956248, total sparse =74796
# [iter: 0020]: rank(P) = 0001, |C|_0 = 15741, crit=0.0000323137, total sparse =74810
# [iter: 0030]: rank(P) = 0001, |C|_0 = 19647, crit=0.0000005693, total sparse =74811
# RPCA takes:0.252525 seconds
# /tmp/tmpRnD5Nh/LRA_Results/Iter3_0.nrrd
# /tmp/tmpRnD5Nh/LRA_Results/Iter3_1.nrrd
# /tmp/tmpRnD5Nh/LRA_Results/Iter3_2.nrrd
# /tmp/tmpRnD5Nh/LRA_Results/Iter3_3.nrrd
# /tmp/tmpRnD5Nh/LRA_Results/Iter3_4.nrrd
# /tmp/tmpRnD5Nh/LRA_Results/Iter3_5.nrrd
# /tmp/tmpRnD5Nh/LRA_Results/Iter3_6.nrrd
# /tmp/tmpRnD5Nh/LRA_Results/Iter3_7.nrrd
# iter4
# [iter: 0000]: rank(P) = 0001, |C|_0 = 5195, crit=0.3105391119, total sparse =150470
# [iter: 0010]: rank(P) = 0001, |C|_0 = 10050, crit=0.0021265490, total sparse =74552
# [iter: 0020]: rank(P) = 0001, |C|_0 = 15751, crit=0.0000328401, total sparse =74537
# [iter: 0030]: rank(P) = 0001, |C|_0 = 19838, crit=0.0000005769, total sparse =74539
# RPCA takes:0.306327 seconds
# /tmp/tmpRnD5Nh/LRA_Results/Iter4_0.nrrd
# /tmp/tmpRnD5Nh/LRA_Results/Iter4_1.nrrd
# /tmp/tmpRnD5Nh/LRA_Results/Iter4_2.nrrd
# /tmp/tmpRnD5Nh/LRA_Results/Iter4_3.nrrd
# /tmp/tmpRnD5Nh/LRA_Results/Iter4_4.nrrd
# /tmp/tmpRnD5Nh/LRA_Results/Iter4_5.nrrd
# /tmp/tmpRnD5Nh/LRA_Results/Iter4_6.nrrd
# /tmp/tmpRnD5Nh/LRA_Results/Iter4_7.nrrd
# iter5
# [iter: 0000]: rank(P) = 0001, |C|_0 = 5193, crit=0.3106251472, total sparse =150446
# [iter: 0010]: rank(P) = 0001, |C|_0 = 9983, crit=0.0020652555, total sparse =74497
# [iter: 0020]: rank(P) = 0001, |C|_0 = 15320, crit=0.0000331115, total sparse =74446
# [iter: 0030]: rank(P) = 0001, |C|_0 = 19596, crit=0.0000005889, total sparse =74449
# RPCA takes:0.291419 seconds
# /tmp/tmpRnD5Nh/LRA_Results/Iter5_0.nrrd
# /tmp/tmpRnD5Nh/LRA_Results/Iter5_1.nrrd
# /tmp/tmpRnD5Nh/LRA_Results/Iter5_2.nrrd
# /tmp/tmpRnD5Nh/LRA_Results/Iter5_3.nrrd
# /tmp/tmpRnD5Nh/LRA_Results/Iter5_4.nrrd
# /tmp/tmpRnD5Nh/LRA_Results/Iter5_5.nrrd
# /tmp/tmpRnD5Nh/LRA_Results/Iter5_6.nrrd
# /tmp/tmpRnD5Nh/LRA_Results/Iter5_7.nrrd
# iter6
# [iter: 0000]: rank(P) = 0001, |C|_0 = 5195, crit=0.3105293967, total sparse =150482
# [iter: 0010]: rank(P) = 0001, |C|_0 = 10058, crit=0.0021436918, total sparse =74512
# [iter: 0020]: rank(P) = 0001, |C|_0 = 15625, crit=0.0000321925, total sparse =74526
# [iter: 0030]: rank(P) = 0001, |C|_0 = 19692, crit=0.0000005920, total sparse =74530
# RPCA takes:0.344851 seconds
# /tmp/tmpRnD5Nh/LRA_Results/Iter6_0.nrrd
# /tmp/tmpRnD5Nh/LRA_Results/Iter6_1.nrrd
# /tmp/tmpRnD5Nh/LRA_Results/Iter6_2.nrrd
# /tmp/tmpRnD5Nh/LRA_Results/Iter6_3.nrrd
# /tmp/tmpRnD5Nh/LRA_Results/Iter6_4.nrrd
# /tmp/tmpRnD5Nh/LRA_Results/Iter6_5.nrrd
# /tmp/tmpRnD5Nh/LRA_Results/Iter6_6.nrrd
# /tmp/tmpRnD5Nh/LRA_Results/Iter6_7.nrrd
# iter7
# [iter: 0000]: rank(P) = 0001, |C|_0 = 5193, crit=0.3105165698, total sparse =150483
# [iter: 0010]: rank(P) = 0001, |C|_0 = 10135, crit=0.0021123219, total sparse =74646
# [iter: 0020]: rank(P) = 0001, |C|_0 = 15821, crit=0.0000331038, total sparse =74648
# [iter: 0030]: rank(P) = 0001, |C|_0 = 19956, crit=0.0000005482, total sparse =74650
# RPCA takes:0.332948 seconds
# /tmp/tmpRnD5Nh/LRA_Results/Iter7_0.nrrd
# /tmp/tmpRnD5Nh/LRA_Results/Iter7_1.nrrd
# /tmp/tmpRnD5Nh/LRA_Results/Iter7_2.nrrd
# /tmp/tmpRnD5Nh/LRA_Results/Iter7_3.nrrd
# /tmp/tmpRnD5Nh/LRA_Results/Iter7_4.nrrd
# /tmp/tmpRnD5Nh/LRA_Results/Iter7_5.nrrd
# /tmp/tmpRnD5Nh/LRA_Results/Iter7_6.nrrd
# /tmp/tmpRnD5Nh/LRA_Results/Iter7_7.nrrd
# iter8
# [iter: 0000]: rank(P) = 0001, |C|_0 = 5194, crit=0.3104096825, total sparse =150499
# [iter: 0010]: rank(P) = 0001, |C|_0 = 9931, crit=0.0022373655, total sparse =74411
# [iter: 0020]: rank(P) = 0001, |C|_0 = 16043, crit=0.0000325215, total sparse =74517
# [iter: 0030]: rank(P) = 0001, |C|_0 = 20108, crit=0.0000005290, total sparse =74517
# RPCA takes:0.399696 seconds
# /tmp/tmpRnD5Nh/LRA_Results/Iter8_0.nrrd
# /tmp/tmpRnD5Nh/LRA_Results/Iter8_1.nrrd
# /tmp/tmpRnD5Nh/LRA_Results/Iter8_2.nrrd
# /tmp/tmpRnD5Nh/LRA_Results/Iter8_3.nrrd
# /tmp/tmpRnD5Nh/LRA_Results/Iter8_4.nrrd
# /tmp/tmpRnD5Nh/LRA_Results/Iter8_5.nrrd
# /tmp/tmpRnD5Nh/LRA_Results/Iter8_6.nrrd
# /tmp/tmpRnD5Nh/LRA_Results/Iter8_7.nrrd
# iter9
# [iter: 0000]: rank(P) = 0001, |C|_0 = 5193, crit=0.3104524467, total sparse =150514
# [iter: 0010]: rank(P) = 0001, |C|_0 = 9943, crit=0.0021719268, total sparse =74462
# [iter: 0020]: rank(P) = 0001, |C|_0 = 16118, crit=0.0000307944, total sparse =74514
# [iter: 0030]: rank(P) = 0001, |C|_0 = 20201, crit=0.0000005505, total sparse =74516
# RPCA takes:0.441711 seconds
# /tmp/tmpRnD5Nh/LRA_Results/Iter9_0.nrrd
# /tmp/tmpRnD5Nh/LRA_Results/Iter9_1.nrrd
# /tmp/tmpRnD5Nh/LRA_Results/Iter9_2.nrrd
# /tmp/tmpRnD5Nh/LRA_Results/Iter9_3.nrrd
# /tmp/tmpRnD5Nh/LRA_Results/Iter9_4.nrrd
# /tmp/tmpRnD5Nh/LRA_Results/Iter9_5.nrrd
# /tmp/tmpRnD5Nh/LRA_Results/Iter9_6.nrrd
# /tmp/tmpRnD5Nh/LRA_Results/Iter9_7.nrrd
# iter10
# [iter: 0000]: rank(P) = 0001, |C|_0 = 5195, crit=0.3102779953, total sparse =150529
# [iter: 0010]: rank(P) = 0001, |C|_0 = 10143, crit=0.0022647237, total sparse =74531
# [iter: 0020]: rank(P) = 0001, |C|_0 = 16412, crit=0.0000300591, total sparse =74645
# [iter: 0030]: rank(P) = 0001, |C|_0 = 20501, crit=0.0000005386, total sparse =74646
# RPCA takes:0.441828 seconds
# /tmp/tmpRnD5Nh/LRA_Results/Iter10_0.nrrd
# /tmp/tmpRnD5Nh/LRA_Results/Iter10_1.nrrd
# /tmp/tmpRnD5Nh/LRA_Results/Iter10_2.nrrd
# /tmp/tmpRnD5Nh/LRA_Results/Iter10_3.nrrd
# /tmp/tmpRnD5Nh/LRA_Results/Iter10_4.nrrd
# /tmp/tmpRnD5Nh/LRA_Results/Iter10_5.nrrd
# /tmp/tmpRnD5Nh/LRA_Results/Iter10_6.nrrd
# /tmp/tmpRnD5Nh/LRA_Results/Iter10_7.nrrd
# max = 0.60756812848
# min = -16.4602781492
# total ssd =  75407.9641547
# geodesic distance =  0.0
# [ 75407.96415471]
# [ 0.]
