# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import nibabel as nib
import numpy as np
def plot_slice(fname, z_idx=5):
    # Load the image and collect the data
    # and orientation information
    img = nib.load(fname)
    data = img.get_data()
    aff = img.get_affine()
    # Find the center of the brain matrix
    ctr = np.dot(np.linalg.inv(aff), [0, 0, 0, 1])[:3]
    # Plot the data
    #vmin, vmax = (0, 1) if data.dtype == np.int16 else (30, 150)
    vmin, vmax = (30, 150)
    imshow(data[:, :, ctr[2] + z_idx], 
           cmap="gray")
    xticks(()); yticks(())
plot_slice("/home/fbudin/Data/BRATS_from_Virtual_Skeleton_Databa_project/BRATS_Training/BRATS-2/Image_Data/LG/0011/VSD.Brain.XX.O.MR_T1/VSD.Brain.XX.O.MR_T1.836.nii.gz",100)
# Out:
# /home/fbudin/tutorial-env/lib/python2.7/site-packages/ipykernel/__main__.py:13: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future

# %%
#!standard_space_roi /Users/xiaoxiaoliu/work/data/BrainWeb-T1/05.nii.gz /Users/xiaoxiaoliu/work/data/BrainWeb-T1/05_roi.nii.gz -b
# !bet /Users/xiaoxiaoliu/work/data/BrainWeb-T1/05.nii.gz /Users/xiaoxiaoliu/work/data/BrainWeb-T1/05_strip.nii.gz
#
plot_slice("/Users/xiaoxiaoliu/work/data/BrainWeb-T1/05_strip.nii.gz",90)
